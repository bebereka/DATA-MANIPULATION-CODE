# %%
print("hello world")
# Out:
# hello world

# %%
#create a lists of values

# %%
import pandas as pd

# %%
data=[10,20,30,40,50]

# %%
#create a series with default index

# %%
my_series = pd.Series(data)

# %%
print(my_series)
# Out:
# 0    10
# 1    20
# 2    30
# 3    40
# 4    50
# dtype: int64

# %%
#declaring your own index

# %%
Index = ["A","B","C","D","E"]

# %%
#UPDATED SERIES,

# %%
updated_series = pd.Series(data,Index)

# %%
print(updated_series)
# Out:
# A    10
# B    20
# C    30
# D    40
# E    50
# dtype: int64

# %%
updated_series['c']=45

# %%
print(updated_series['c'])
# Out:
# 45

# %%
updated_series['f']=60

# %%
print(updated_series['f'])
# Out:
# 60

# %%
population = {
 'California': 39538223,
 'Texas': 29145505,
 'Florida': 21538187,
 'New York': 20201249,}

# %%
df = pd.DataFrame(population,index = Index)

# %%
df
# Out:
#    California     Texas   Florida  New York
# A    39538223  29145505  21538187  20201249
# B    39538223  29145505  21538187  20201249
# C    39538223  29145505  21538187  20201249
# D    39538223  29145505  21538187  20201249
# E    39538223  29145505  21538187  20201249

# %%
pop_series=pd.Series(population)

# %%
print (pop_series)
# Out:
# California    39538223
# Texas         29145505
# Florida       21538187
# New York      20201249
# dtype: int64

# %%
data = {
 'State': ['California', 'Texas', 'Florida', 'New York'],
 'Population': [39538223, 29145505, 21538187, 20201249],
 'Area_sq_km': [423970, 695662, 170312, 141297]}

# %%
df = pd.DataFrame(data)

# %%
df
# Out:
#         State  Population  Area_sq_km
# 0  California    39538223      423970
# 1       Texas    29145505      695662
# 2     Florida    21538187      170312
# 3    New York    20201249      141297
