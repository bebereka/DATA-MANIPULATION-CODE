# %%
print("hello world")
# Out:
# hello world

# %%
#create a lists of values

# %%
import pandas as pd

# %%
data=[10,20,30,40,50]

# %%
#create a series with default index

# %%
my_series = pd.Series(data)

# %%
print(my_series)
# Out:
# 0    10
# 1    20
# 2    30
# 3    40
# 4    50
# dtype: int64

# %%
#declaring your own index

# %%
Index = ["A","B","C","D","E"]

# %%
#UPDATED SERIES,

# %%
updated_series = pd.Series(data,Index)

# %%
print(updated_series)
# Out:
# A    10
# B    20
# C    30
# D    40
# E    50
# dtype: int64
